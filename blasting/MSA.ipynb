# %% [markdown]
# Multiple Sequence Alignment is performed with Clustal Omega. First the package is imported and then applied to the FASTA file "pdb_sequences.fasta".

# %%
import subprocess

subprocess.run([
    "clustalo",
    "-i", "pdb_sequences.fasta",   # Input file
    "-o", "aligned_pdb_sequences.aln",           # Output file (alignment)
    "--outfmt", "clu",
    "--force"
])
# Out:
# CompletedProcess(args=['clustalo', '-i', 'pdb_sequences.fasta', '-o', 'aligned.aln', '--outfmt', 'clu', '--force'], returncode=0)
