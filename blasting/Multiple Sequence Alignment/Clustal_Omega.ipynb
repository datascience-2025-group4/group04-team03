# %% [markdown]
# Multiple Sequence Alignment is performed with Clustal Omega. First the package is imported and then applied to the FASTA file "pdb_sequences.fasta".

# %%
from Bio import SeqIO

input_fasta = "annotated_antibody_only.fasta"
output_fasta = "annotated_antibody.fasta"

with open(output_fasta, 'w') as out_f:
    for record in SeqIO.parse(input_fasta, "fasta"):
        # Original header example:
        # 7ZOZ_2|H|Homo sapiens | antigen_species=homo sapiens

        parts = record.description.split("|")
        pdb_chain = parts[0]  # e.g. '7ZOZ_2'
        chain = parts[1]      # e.g. 'H'

        # Find antigen_species in the header:
        antigen_species = None
        for part in parts[2:]:
            if "antigen_species=" in part:
                antigen_species = part.split("antigen_species=")[1].strip()
                break

        # Build new header: keep pdb_chain and chain, replace species with antigen species
        if antigen_species:
            new_header = f"{pdb_chain}|{chain}|antigen_species={antigen_species}"
        else:
            new_header = record.description  # fallback if no antigen species found

        # Write out record with new header
        out_f.write(f">{new_header}\n{record.seq}\n")

# %%
import subprocess

subprocess.run([
    "clustalo",
    "-i", "annotated_antibody.fasta",   # Input file (was pdb_sequences_fasta)
    "-o", "aligned_annotated_antibody_sequences.aln",           # Output file (alignment)
    "--outfmt", "clu",
    "--force"
])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import subprocess
# ----> 3 subprocess.run([
#       4     "clustalo",
#       5     "-i", "annotated_antibody.fasta",   # Input file (was pdb_sequences_fasta)
#       6     "-o", "aligned_annotated_antibody_sequences.aln",           # Output file (alignment)
#       7     "--outfmt", "clu",
#       8     "--force"
#       9 ])
#
# File ~/miniconda3/lib/python3.13/subprocess.py:558, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     556 with Popen(*popenargs, **kwargs) as process:
#     557     try:
# --> 558         stdout, stderr = process.communicate(input, timeout=timeout)
#     559     except TimeoutExpired as exc:
#     560         process.kill()
#
# File ~/miniconda3/lib/python3.13/subprocess.py:1213, in Popen.communicate(self, input, timeout)
#    1211         stderr = self.stderr.read()
#    1212         self.stderr.close()
# -> 1213     self.wait()
#    1214 else:
#    1215     if timeout is not None:
#
# File ~/miniconda3/lib/python3.13/subprocess.py:1276, in Popen.wait(self, timeout)
#    1274     endtime = _time() + timeout
#    1275 try:
# -> 1276     return self._wait(timeout=timeout)
#    1277 except KeyboardInterrupt:
#    1278     # https://bugs.python.org/issue25942
#    1279     # The first keyboard interrupt waits briefly for the child to
#    1280     # exit under the common assumption that it also received the ^C
#    1281     # generated SIGINT and will exit rapidly.
#    1282     if timeout is not None:
#
# File ~/miniconda3/lib/python3.13/subprocess.py:2068, in Popen._wait(self, timeout)
#    2066 if self.returncode is not None:
#    2067     break  # Another thread waited.
# -> 2068 (pid, sts) = self._try_wait(0)
#    2069 # Check the pid and loop as waitpid has been known to
#    2070 # return 0 even without WNOHANG in odd situations.
#    2071 # http://bugs.python.org/issue14396.
#    2072 if pid == self.pid:
#
# File ~/miniconda3/lib/python3.13/subprocess.py:2026, in Popen._try_wait(self, wait_flags)
#    2024 """All callers to this function MUST hold self._waitpid_lock."""
#    2025 try:
# -> 2026     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2027 except ChildProcessError:
#    2028     # This happens if SIGCLD is set to be ignored or waiting
#    2029     # for child processes has otherwise been disabled for our
#    2030     # process.  This child is dead, we can't get the status.
#    2031     pid = self.pid
#
# KeyboardInterrupt:
